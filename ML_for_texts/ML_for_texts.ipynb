# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# Thank you so much for the updates! This project is hard and very time-consuming because of heavy models. You did an excellent job here, and I hope you enjoyed it.
#
#
# I've left a couple of new comments with digit 4. However, I do not have any questions, so the project can be accepted.
#
#
#
# By the way, Hugging Face has a good free [NLP course](https://huggingface.co/learn/nlp-course/en/chapter0/1).
#
#
# Here's a link to [AI for beginners](https://github.com/microsoft/ai-for-beginners) course by Microsoft.
#
# Good luck!
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
# I see your comments, thank you so much! Please run everything except BERT. It will not take hours if you don't run BERT. It should take about 20 minutes and even less. After you run it, please describe the models' performance.
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you so much for the updates! Would you take a look at my new commments with digit 2? Consider [comment #8](#1) and [comment #29](#2).
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, I am a reviewer on this project. Congratulations on submitting another project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
#
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Great solutions and ideas that can and should be used in the future are in green comments. You have successfully analyzed the distributions, employed advanced techniques such as lemmatization and vectorizing, and trained several models. Great job! The results look very good.
#
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project. I've left several recommendations throughout the project. Please take a look.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
# Issues that must be corrected to achieve accurate results are indicated in red comments. Please note that the project cannot be accepted until these issues are resolved. For instance,
#
#
# - However, would you add small conclusions about each chart in the EDA section? One chart does not have a conclusion.
#
#
#
# - Add the final conclusion please. A well-written conclusion shows how the project met its objectives and provides a concise and understandable summary for those who may not have been involved in the details of the project.
#
#
# There may be other issues that need your attention. I described everything in my comments.
# </div>
# <hr>
#
# <font color='dodgerblue'>**To sum up:**</font> thank you for such an excellent job! You showed strong coding skills and a solid understanding of this topic, which is quite hard. I hope you enjoyed working on this project. The updates should not take much time. If you have any questions, please feel free to ask. I will wait the project for the second review 😊
#
#
# <hr>
#
# Please use some color other than those listed to highlight answers to my comments.
# I would also ask you **not to change, move or delete my comments** to make it easier for me to navigate during the next review.
#
# <hr>
#
# ✍️ If you are interested in Large Language Models, check out [Intro to Large Language Models](https://www.youtube.com/watch?v=zjkBMFhNj_g) and Tokenization [lecture](https://www.youtube.com/watch?v=zduSFxRajkE) by Andrej Karpathy, one of the leading scientists in this area. He has also recently published a very useful video about how he uses LLM [here](https://www.youtube.com/watch?v=EWvNQjAaOHw&feature=youtu.be). This is a comprehensive guide on how to choose the optimal tool for your tasks while saving time and money.
#
# <hr>
#
# 📌 Please feel free to schedule a 1:1 with our tutors or TAs, join daily coworking sessions, or ask questions in the sprint channels on Discord if you need assistance.
# </div>

# %% [markdown]
# # **Sentiment Analysis of Movie Reviews Using NLP and Machine Learning**

# %% [markdown]
# # Project Statement

# %% [markdown]
# The Film Junky Union, a new edgy community for classic movie enthusiasts, is developing a system for filtering and categorizing movie reviews. The goal is to train a model to automatically detect negative reviews. You'll be using a dataset of IMBD movie reviews with polarity labelling to build a model for classifying positive and negative reviews. It will need to have an F1 score of at least 0.85.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Good introduction!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Please do not forget about project title :) A title should reflect the core goal of the project.
#
# </div>

# %% [markdown]
# ## Initialization

# %%
import math

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from tqdm.auto import tqdm

import re
import nltk
from nltk.corpus import stopwords

import torch
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, BertModel

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
# the next line provides graphs of better quality on HiDPI screens
# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# %%
# this is to use progress_apply, read more at https://pypi.org/project/tqdm/#pandas-integration
tqdm.pandas()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# It's a very useful thing, by the way.
# </div>

# %% [markdown]
# ## Load Data

# %%
df_reviews = pd.read_csv('/datasets/imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})

# %%
# Basic dataset info
print("Dataset Info:")
print(df_reviews.info())

# Display first few rows
print("\nSample Data:")
print(df_reviews.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47331 entries, 0 to 47330
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           47331 non-null  object
#  1   title_type       47331 non-null  object
#  2   primary_title    47331 non-null  object
#  3   original_title   47331 non-null  object
#  4   start_year       47331 non-null  int64
#  5   end_year         47331 non-null  object
#  6   runtime_minutes  47331 non-null  object
#  7   is_adult         47331 non-null  int64
#  8   genres           47331 non-null  object
#  9   average_rating   47329 non-null  float64
#  10  votes            47329 non-null  Int64
#  11  review           47331 non-null  object
#  12  rating           47331 non-null  int64
#  13  sp               47331 non-null  object
#  14  pos              47331 non-null  int64
#  15  ds_part          47331 non-null  object
# ...

# %%
# Check for missing values
print("\nMissing Values:")
print(df_reviews.isnull().sum())
# Out:
# Missing Values:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     2
# votes              2
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %%
# Drop rows with missing values because only 2 are missing
df_reviews = df_reviews.dropna(subset=['average_rating', 'votes']).reset_index(drop=True)

# Verify missing values are removed
print("\nMissing Values After Cleaning:")
print(df_reviews.isnull().sum())
# Out:
# Missing Values After Cleaning:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     0
# votes              0
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %%
# Check for duplicate rows in the entire dataset
duplicate_rows = df_reviews.duplicated().sum()
print(f"Total duplicate rows: {duplicate_rows}")
# Out:
# Total duplicate rows: 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Good! </div>

# %% [markdown]
# ## EDA

# %% [markdown]
# Let's check the number of movies and reviews over years.

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2021))).fillna(0)
dft1.plot(kind='bar', ax=ax)
ax.set_title('Number of Movies Over Years')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)

dft2.plot(kind='bar', stacked=True, label='#reviews (neg, pos)', ax=ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop=True).rolling(5).mean().plot(color='orange', label='reviews per movie (avg over 5 years)', ax=axt)

lines, labels = axt.get_legend_handles_labels()
ax.legend(lines, labels, loc='upper left')

ax.set_title('Number of Reviews Over Years')

fig.tight_layout()

# %% [markdown]
# <a id=1></a>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# The conclusion is still missing here.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Nice charts!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# However, what can we infer from them? Would you please add a small conclusion?
#
# </div>

# %% [markdown]
# ### findings from the output
#
# The first graph shows that the number of movies produced has increased significantly over time, peaking in the early 2000s. However, there is a sudden drop after 2010, which could be due to changes in data availability or industry shifts.
#
# The second graph indicates that while the number of reviews per year has grown alongside movie production, the average number of reviews per movie has fluctuated. The peak in the 2000s suggests that online review platforms became more popular during this time. However, after 2010, the decline in reviews per movie may indicate reduced engagement or fewer available data points for newer films.
#
# Overall, these trends highlight how the film industry and audience engagement with reviews have evolved over time.

# %% [markdown]
# Let's check the distribution of number of reviews per movie with the exact counting and KDE (just to learn how it may differ from the exact counting)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Bar Plot of #Reviews Per Movie')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('KDE Plot of #Reviews Per Movie')

fig.tight_layout()

# %% [markdown]
# ### Observations from the Review Distribution Graphs
#
# - The **Bar Plot** shows that the majority of movies have **only 1-2 reviews**, indicating that a significant portion of movies are underrepresented in the dataset.
# - The **long-tail distribution** suggests that while most movies receive very few reviews, a smaller number of popular movies accumulate many reviews.
# - The **KDE Plot** confirms this trend, highlighting a **sharp peak** around 1-2 reviews and a gradual decline, with a few movies having significantly more reviews.
# - There are **minor peaks at higher review counts**, suggesting that certain movies have gained widespread engagement, possibly due to their popularity or controversy.
# - The imbalance in the number of reviews per movie may **impact model performance**, as some movies will have richer sentiment data while others may be underrepresented.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Correct.
# </div>

# %%
df_reviews['pos'].value_counts()
# Out:
# 0    23715
# 1    23614
# Name: pos, dtype: int64

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('The train set: distribution of ratings')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('The test set: distribution of ratings')

fig.tight_layout()

# %% [markdown]
# ### Observations from Rating Distribution Graphs
#
# - The distribution of ratings in both the **train and test sets** follows a similar pattern, confirming a well-balanced split.
# - Ratings **1 and 10** have the highest frequency, indicating that many reviews are **strongly polarized**.
# - Intermediate ratings (5 and 6) have **very few reviews**, suggesting that users tend to leave extreme ratings rather than neutral ones.
# - The dataset contains a **balanced number of positive and negative reviews** (`pos` column), ensuring no significant bias towards one class.
# - This polarization in ratings may impact sentiment classification, as extreme ratings are easier to classify, while mid-range ratings may introduce ambiguity.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Yes, the distrbutions of the training and test sets are quite similar.
#
# </div>

# %% [markdown]
# Distribution of negative and positive reviews over the years for two parts of the dataset

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('The train set: number of reviews of different polarities per year')

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('The train set: distribution of different polarities per movie')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('The test set: number of reviews of different polarities per year')

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('The test set: distribution of different polarities per movie')

fig.tight_layout()
# Out:
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)
# /opt/conda/envs/python3/lib/python3.9/site-packages/seaborn/distributions.py:1666: UserWarning: Support for alternate kernels has been removed. Using Gaussian kernel.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Observations from Sentiment Polarity Distribution Graphs
#
# - The **bar plots** show that both positive and negative reviews have been fairly consistent over the years, with a significant increase in reviews after the **1990s**.
# - The **number of reviews per year** has risen sharply, particularly in the **2000s**, aligning with the rise of online review platforms.
# - The **KDE plots** suggest that most movies receive **only a few reviews**, with the highest density around **1-3 reviews per movie**.
# - The **positive and negative review distributions** are similar, indicating a **balanced dataset** with no significant bias toward one sentiment.
# - The presence of movies with **a large number of reviews** suggests that certain films attract a disproportionately higher amount of audience engagement.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Agreed.
#
# </div>

# %% [markdown]
# ## Evaluation Procedure

# %% [markdown]
# Composing an evaluation routine which can be used for all models in this project

# %%
import sklearn.metrics as metrics

def evaluate_model(model, train_features, train_target, test_features, test_target):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize=(20, 6)) 
    
    for type, features, target in (('train', train_features, train_target), ('test', test_features, test_target)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # F1 Score
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, color=color, label=f'{type}, max={f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')
        ax.set_ylabel('F1')
        ax.legend(loc='lower center')
        ax.set_title(f'F1 Score') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'ROC Curve')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color=color, label=f'{type}, AP={aps:.2f}')
        # setting crosses for some thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc='lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Accuracy'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Accuracy', 'F1', 'APS', 'ROC AUC'))
    
    print(df_eval_stats)
    
    return

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment </h2>
#
#
# - According to [PEP8](https://peps.python.org/pep-0008/), we should always put imports at the top of the file.
#
#
# - Notice that **type** veriable is green in the function above. When you see that your variables are green, you should think of another name, since green color indicates that this name is reserved in python. I know it was in the precode, but it is a great opportunity to point out this thing.
# </div>

# %% [markdown]
# ## Normalization

# %% [markdown]
# We assume all models below accepts texts in lowercase and without any digits, punctuations marks etc.

# %%
# Define a text normalization function
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^a-z\s]', '', text)  # Remove punctuation and numbers
    text = " ".join([word for word in text.split() if word not in stopwords.words('english')])  # Remove stopwords
    return text
 
# Apply normalization
df_reviews['review_norm'] = df_reviews['review'].apply(normalize_text)

# Display sample results
print(df_reviews[['review', 'review_norm']].head(5))
# Out:
#                                               review  \
# 0  The pakage implies that Warren Beatty and Gold...
# 1  How the hell did they get this made?! Presenti...
# 2  There is no real story the film seems more lik...
# 3  Um .... a serious film about troubled teens in...
# 4  I'm totally agree with GarryJohal from Singapo...
#
#                                          review_norm
# 0  pakage implies warren beatty goldie hawn pulli...
# 1  hell get made presenting caper comedy misbegot...
# 2  real story film seems like fly wall dramadocum...
# 3  um serious film troubled teens singapore count...
# 4  im totally agree garryjohal singapores comment...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Nice code!
# </div>

# %% [markdown]
# ## Train / Test Split

# %% [markdown]
# Luckily, the whole dataset is already divided into train/test one parts. The corresponding flag is 'ds_part'.

# %%
df_reviews_train = df_reviews.query('ds_part == "train"').copy()
df_reviews_test = df_reviews.query('ds_part == "test"').copy()

train_target = df_reviews_train['pos']
test_target = df_reviews_test['pos']

print(df_reviews_train.shape)
print(df_reviews_test.shape)
# Out:
# (23796, 18)
# (23533, 18)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Correct.
#
# </div>

# %% [markdown]
# ## Working with models

# %% [markdown]
# ### Model 0 - Constant

# %%
from sklearn.dummy import DummyClassifier

# %%
# Initialize DummyClassifier with strategy to always predict the most frequent class
model_0 = DummyClassifier(strategy="most_frequent")

# Train the model
model_0.fit(train_target.values.reshape(-1, 1), train_target)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
# Evaluate using the pre-coded function
evaluate_model(model_0, train_target.values.reshape(-1, 1), train_target,
               test_target.values.reshape(-1, 1), test_target)
# Out:
#           train  test
# Accuracy    0.5   0.5
# F1          0.0   0.0
# APS         0.5   0.5
# ROC AUC     0.5   0.5

# %% [markdown]
# #### Observations for Model 0 - Constant (Baseline)
#
# The **Dummy Classifier (Baseline Model)** was trained using the **most frequent strategy**, meaning it always predicts the majority class. The evaluation results show:
#
# - **Accuracy: 50%** for both train and test sets.
# - **F1 Score: 0.0**, meaning the model fails to classify the minority class.
# - **ROC AUC: 0.5**, indicating random guessing.
# - **APS (Average Precision Score): 0.5**, also suggesting no predictive capability.
#
# The **F1 Score of 0.0** confirms that this model is ineffective for sentiment classification. This baseline sets a **minimum benchmark**, meaning any real model must perform **significantly better** to be considered useful.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Good. You can also check the result using different strategy values.
# </div>

# %% [markdown]
# ### Model 1 - NLTK, TF-IDF and LR

# %% [markdown]
# TF-IDF

# %%
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from nltk.corpus import stopwords

# %%
# Initialize TF-IDF Vectorizer
tfidf_vectorizer_1 = TfidfVectorizer(stop_words=stopwords.words('english'), max_features=5000)

# Transform training & testing text data
train_features_1 = tfidf_vectorizer_1.fit_transform(df_reviews_train['review_norm'])
test_features_1 = tfidf_vectorizer_1.transform(df_reviews_test['review_norm'])

# %%
# Initialize and train Logistic Regression model
model_1 = LogisticRegression(max_iter=1000)
model_1.fit(train_features_1, train_target)
# Out:
# LogisticRegression(max_iter=1000)

# %%
evaluate_model(model_1, train_features_1, train_target, test_features_1, test_target)
# Out:
#           train  test
# Accuracy   0.92  0.88
# F1         0.92  0.88
# APS        0.97  0.95
# ROC AUC    0.97  0.95

# %% [markdown]
# #### Observations for Model 1 - NLTK, TF-IDF, and Logistic Regression
#
# The **Logistic Regression model** trained using **TF-IDF vectorization** and **NLTK preprocessing** performed significantly better than the baseline. Key observations:
#
# - **Accuracy:** 92% on the training set and 88% on the test set.
# - **F1 Score:** 0.92 (train) and 0.88 (test), indicating strong predictive power.
# - **ROC AUC:** 0.97 (train) and 0.95 (test), suggesting excellent class separation.
# - **APS (Average Precision Score):** 0.97 (train) and 0.95 (test), confirming the model’s confidence in its predictions.
#
# The **ROC and PRC curves** show **high precision and recall**, demonstrating the model’s ability to distinguish between positive and negative reviews effectively.
#
# The model **meets the F1 score threshold of 0.85**, making it a viable option for review classification.
#
# **Next Steps:** Proceed with **Model 3 - spaCy, TF-IDF, and Logistic Regression**, and evaluate its performance.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Correct. The model exceeds the F1 threshold and has good precision.
#
# </div>

# %% [markdown]
# ### Model 3 - spaCy, TF-IDF and LR

# %%
import spacy

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def text_preprocessing_3(text):
    
    doc = nlp(text)
    #tokens = [token.lemma_ for token in doc if not token.is_stop]
    tokens = [token.lemma_ for token in doc]
    
    return ' '.join(tokens)

# %%
# Apply text preprocessing to train and test reviews
df_reviews_train['review_norm_3'] = df_reviews_train['review_norm'].apply(text_preprocessing_3)
df_reviews_test['review_norm_3'] = df_reviews_test['review_norm'].apply(text_preprocessing_3)

# %%
# TF-IDF Vectorization
tfidf_vectorizer_3 = TfidfVectorizer()
train_features_3 = tfidf_vectorizer_3.fit_transform(df_reviews_train['review_norm_3'])
test_features_3 = tfidf_vectorizer_3.transform(df_reviews_test['review_norm_3'])

# %%
# Train the Logistic Regression model
model_3 = LogisticRegression(max_iter=1000)
model_3.fit(train_features_3, train_target)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Evaluate the model
evaluate_model(model_3, train_features_3, train_target, test_features_3, test_target)
# Out:
#           train  test
# Accuracy   0.93  0.88
# F1         0.93  0.88
# APS        0.98  0.95
# ROC AUC    0.98  0.95

# %% [markdown]
# #### Observations from Model 3 (spaCy, TF-IDF, and Logistic Regression)
#
# The Logistic Regression model trained with spaCy-based preprocessing and TF-IDF transformation performed well. The training set achieved an **F1 score of 0.93**, while the test set reached **0.88**, indicating a slight drop but still strong generalization. The **ROC AUC** scores were **0.98 for training and 0.95 for testing**, suggesting that the model effectively distinguishes between positive and negative reviews. The **PRC curve** also highlights a high **average precision score (APS) of 0.98 on training and 0.95 on testing**, reinforcing the model’s ability to rank predictions accurately. Overall, this model shows strong performance in sentiment classification.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# We see quite similar performance.
#
# </div>

# %% [markdown]
# ### Model 4 - spaCy, TF-IDF and LGBMClassifier

# %%
from lightgbm import LGBMClassifier

# %%
# TF-IDF Vectorization using the same preprocessing as Model 3
tfidf_vectorizer_4 = tfidf_vectorizer_3  # Reuse vectorizer from Model 3
train_features_4 = tfidf_vectorizer_4.transform(df_reviews_train['review_norm_3'])
test_features_4 = tfidf_vectorizer_4.transform(df_reviews_test['review_norm_3'])

# %%
# Initialize and train the LightGBM classifier
model_4 = LGBMClassifier(n_estimators=200, learning_rate=0.1, random_state=42)
model_4.fit(train_features_4, train_target)
# Out:
# LGBMClassifier(n_estimators=200, random_state=42)

# %%
# Evaluate the model
evaluate_model(model_4, train_features_4, train_target, test_features_4, test_target)
# Out:
#           train  test
# Accuracy   0.96  0.87
# F1         0.96  0.87
# APS        0.99  0.94
# ROC AUC    0.99  0.94

# %% [markdown]
# #### Observations from Model 4 (spaCy, TF-IDF, and LightGBM)
#
# The LightGBM classifier performed well, achieving an **F1 score of 0.96 on training** and **0.87 on testing**, indicating strong learning with a slight drop in generalization. The **ROC AUC score** was **0.99 for training and 0.94 for testing**, suggesting the model effectively differentiates between positive and negative reviews. The **PRC curve** shows an **APS of 0.99 on training and 0.94 on testing**, demonstrating excellent ranking ability. The model is highly performant, but the slight drop in test performance suggests minor overfitting.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Good.
#
# </div>

# %% [markdown]
# ###  Model 9 - BERT

# %%
import torch
import transformers

# %%
# Load BERT tokenizer & model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
"""from transformers import BertTokenizer, BertModel

def BERT_text_to_embeddings(texts, max_length=32, batch_size=512, force_device="cpu", disable_progress_bar=False):
  
    # Tokenize & pad texts
    encoded_dict = tokenizer.batch_encode_plus(
        texts.tolist(),
        add_special_tokens=True,
        max_length=max_length,
        padding="max_length",
        truncation=True,
        return_tensors="pt"
    )

    # Keep `input_ids` as LongTensor (Fix RuntimeError)
    input_ids = encoded_dict["input_ids"].to(torch.long)  
    attention_mask = encoded_dict["attention_mask"].to(torch.float16)  # Float16 for speed

    # Device selection
    device = torch.device(force_device)
    model.to(device).eval()

    # Process in Batches
    embeddings = []
    for i in tqdm(range(math.ceil(len(input_ids) / batch_size)), disable=disable_progress_bar):
        batch_input_ids = input_ids[batch_size * i: batch_size * (i + 1)].to(device)
        batch_attention_mask = attention_mask[batch_size * i: batch_size * (i + 1)].to(device)

        with torch.no_grad():
            batch_embeddings = model(batch_input_ids, attention_mask=batch_attention_mask)
            embeddings.append(batch_embeddings[0][:, 0, :].detach().cpu().numpy())

    return np.concatenate(embeddings, axis=0)"""
# Out:
# 'from transformers import BertTokenizer, BertModel\n\ndef BERT_text_to_embeddings(texts, max_length=32, batch_size=512, force_device="cpu", disable_progress_bar=False):\n  \n    # Tokenize & pad texts\n    encoded_dict = tokenizer.batch_encode_plus(\n        texts.tolist(),\n        add_special_tokens=True,\n        max_length=max_length,\n        padding="max_length",\n        truncation=True,\n        return_tensors="pt"\n    )\n\n    # Keep `input_ids` as LongTensor (Fix RuntimeError)\n    input_ids = encoded_dict["input_ids"].to(torch.long)  \n    attention_mask = encoded_dict["attention_mask"].to(torch.float16)  # Float16 for speed\n\n    # Device selection\n    device = torch.device(force_device)\n    model.to(device).eval()\n\n    # Process in Batches\n    embeddings = []\n    for i in tqdm(range(math.ceil(len(input_ids) / batch_size)), disable=disable_progress_bar):\n        batch_input_ids = input_ids[batch_size * i: batch_size * (i + 1)].to(device)\n        batch_attention_
# ...

# %%
"""# Attention! Running BERT for thousands of texts may take long run on CPU, at least several hours
train_features_9 = BERT_text_to_embeddings(df_reviews_train['review_norm'], force_device='cpu')"""
# Out:
# "# Attention! Running BERT for thousands of texts may take long run on CPU, at least several hours\ntrain_features_9 = BERT_text_to_embeddings(df_reviews_train['review_norm'], force_device='cpu')"

# %%
"""print(df_reviews_train['review_norm'].shape)
print(train_features_9.shape)
print(train_target.shape)"""
# Out:
# "print(df_reviews_train['review_norm'].shape)\nprint(train_features_9.shape)\nprint(train_target.shape)"

# %%
""""# Generate test set features using BERT
test_features_9 = BERT_text_to_embeddings(df_reviews_test['review_norm'], force_device='cuda')"""
# Out:
# '"# Generate test set features using BERT\ntest_features_9 = BERT_text_to_embeddings(df_reviews_test[\'review_norm\'], force_device=\'cuda\')'

# %%
"""# Save BERT embeddings to avoid recomputation
np.savez_compressed('features_9.npz', train_features_9=train_features_9, test_features_9=test_features_9)

# Load saved embeddings
with np.load('features_9.npz') as data:
    train_features_9 = data['train_features_9']
    test_features_9 = data['test_features_9']"""
# Out:
# "# Save BERT embeddings to avoid recomputation\nnp.savez_compressed('features_9.npz', train_features_9=train_features_9, test_features_9=test_features_9)\n\n# Load saved embeddings\nwith np.load('features_9.npz') as data:\n    train_features_9 = data['train_features_9']\n    test_features_9 = data['test_features_9']"

# %%
# if you have got the embeddings, it's advisable to save them to have them ready if 
# np.savez_compressed('features_9.npz', train_features_9=train_features_9, test_features_9=test_features_9)

# and load...
# with np.load('features_9.npz') as data:
#     train_features_9 = data['train_features_9']
#     test_features_9 = data['test_features_9']

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Yes, Bert is a hard thing to handle, so we should use GPU for it. By the way, you can use Colab for your practice tasks. It has some free GPU.
#
# </div>

# %% [markdown]
# ## My Reviews

# %%
# feel free to completely remove these reviews and try your models on your own reviews, those below are just examples

my_reviews = pd.DataFrame([
    'I did not simply like it, not my kind of movie.',
    'Well, I was bored and felt asleep in the middle of the movie.',
    'I was really fascinated with the movie',    
    'Even the actors looked really old and disinterested, and they got paid to be in the movie. What a soulless cash grab.',
    'I didn\'t expect the reboot to be so good! Writers really cared about the source material',
    'The movie had its upsides and downsides, but I feel like overall it\'s a decent flick. I could see myself going to see it again.',
    'What a rotten attempt at a comedy. Not a single joke lands, everyone acts annoying and loud, even kids won\'t like this!',
    'Launching on Netflix was a brave move & I really appreciate being able to binge on episode after episode, of this exciting intelligent new drama.'
], columns=['review'])

# Apply the same normalization logic as for the main dataset
my_reviews['review_norm'] = my_reviews['review'].str.lower()
my_reviews['review_norm'] = my_reviews['review_norm'].str.replace(r'[^a-z\s]', '', regex=True)
my_reviews['review_norm'] = my_reviews['review_norm'].str.replace(r'\s+', ' ', regex=True).str.strip()

my_reviews
# Out:
#                                               review  \
# 0    I did not simply like it, not my kind of movie.
# 1  Well, I was bored and felt asleep in the middl...
# 2             I was really fascinated with the movie
# 3  Even the actors looked really old and disinter...
# 4  I didn't expect the reboot to be so good! Writ...
# 5  The movie had its upsides and downsides, but I...
# 6  What a rotten attempt at a comedy. Not a singl...
# 7  Launching on Netflix was a brave move & I real...
#
#                                          review_norm
# 0      i did not simply like it not my kind of movie
# 1  well i was bored and felt asleep in the middle...
# 2             i was really fascinated with the movie
# 3  even the actors looked really old and disinter...
# 4  i didnt expect the reboot to be so good writer...
# 5  the movie had its upsides and downsides but i ...
# 6  what a rotten attempt at a comedy not a single...
# 7  launching on netflix was a brave move i really...

# %% [markdown]
# ### Model 1

# %%
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_1.predict_proba(tfidf_vectorizer_1.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.19:  i did not simply like it not my kind of movie
# 0.16:  well i was bored and felt asleep in the middle of the movie
# 0.60:  i was really fascinated with the movie
# 0.10:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.21:  i didnt expect the reboot to be so good writers really cared about the source material
# 0.54:  the movie had its upsides and downsides but i feel like overall its a decent flick i could see mysel
# 0.05:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.91:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 4 </h2>
#
# Good.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  </b>
#
# There's no `model_2` variable in your project.
# </div>

# %% [markdown]
# ### Model 3

# %%
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_3.predict_proba(tfidf_vectorizer_3.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.14:  i did not simply like it not my kind of movie
# 0.32:  well i was bored and felt asleep in the middle of the movie
# 0.51:  i was really fascinated with the movie
# 0.23:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.32:  i didnt expect the reboot to be so good writers really cared about the source material
# 0.56:  the movie had its upsides and downsides but i feel like overall its a decent flick i could see mysel
# 0.06:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.89:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# ### Model 4

# %%
texts = my_reviews['review_norm']

tfidf_vectorizer_4 = tfidf_vectorizer_3
my_reviews_pred_prob = model_4.predict_proba(tfidf_vectorizer_4.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.40:  i did not simply like it not my kind of movie
# 0.30:  well i was bored and felt asleep in the middle of the movie
# 0.61:  i was really fascinated with the movie
# 0.28:  even the actors looked really old and disinterested and they got paid to be in the movie what a soul
# 0.31:  i didnt expect the reboot to be so good writers really cared about the source material
# 0.76:  the movie had its upsides and downsides but i feel like overall its a decent flick i could see mysel
# 0.11:  what a rotten attempt at a comedy not a single joke lands everyone acts annoying and loud even kids
# 0.85:  launching on netflix was a brave move i really appreciate being able to binge on episode after episo

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 4 </h2>
#
# Nice results!
# </div>

# %% [markdown]
# ### Model 9

# %%
"""texts = my_reviews['review_norm']

my_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)

my_reviews_pred_prob = model_9.predict_proba(my_reviews_features_9)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')"""
# Out:
# "texts = my_reviews['review_norm']\n\nmy_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)\n\nmy_reviews_pred_prob = model_9.predict_proba(my_reviews_features_9)[:, 1]\n\nfor i, review in enumerate(texts.str.slice(0, 100)):\n    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')"

# %% [markdown]
# ## Conclusions

# %% [markdown]
# <a id=2></a>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# The analysis and the general conclusion are missing. Would you add them? You will need to run the code and get the results. Then compare them, analyze models' performance and write the final conclusion.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Please compare the results.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
# Please don't forget to add the overall conclusion to your project: what has been done and what can be inferred from the results.
#
# </div>

# %% [markdown]
# ## Model Comparisons
#
# ### Performance Metrics Overview
#
# | Model  | Accuracy (Train) | Accuracy (Test) | F1 Score (Train) | F1 Score (Test) | APS (Train) | APS (Test) | ROC AUC (Train) | ROC AUC (Test) |
# |--------|----------------|----------------|-----------------|----------------|------------|------------|----------------|----------------|
# | Model 1 (TF-IDF + LR) | 0.92 | 0.88 | 0.92 | 0.88 | 0.97 | 0.95 | 0.97 | 0.95 |
# | Model 3 (spaCy + TF-IDF + LR) | 0.93 | 0.88 | 0.93 | 0.88 | 0.98 | 0.95 | 0.98 | 0.95 |
# | Model 4 (spaCy + TF-IDF + LGBM) | 0.96 | 0.87 | 0.96 | 0.87 | 0.99 | 0.94 | 0.99 | 0.94 |
#
# ### Model Analysis
#
# - **Model 1 (TF-IDF + Logistic Regression)**
#   - This model performs well with a balanced accuracy of **92% (train) and 88% (test)**.
#   - The **F1 score of 0.92 (train) and 0.88 (test)** suggests strong classification capability.
#   - APS and ROC AUC values confirm good model confidence and class separation.
#   - Works efficiently and does not require extensive preprocessing.
#
# - **Model 3 (spaCy + TF-IDF + Logistic Regression)**
#   - Slightly better performance than Model 1 with an accuracy of **93% (train) and 88% (test)**.
#   - The F1 score remains **0.93 (train) and 0.88 (test)**, showing consistent prediction quality.
#   - Preprocessing using **spaCy lemmatization** improves text representation but does not significantly impact the final performance compared to Model 1.
#
# - **Model 4 (spaCy + TF-IDF + LGBM)**
#   - Achieves the highest accuracy of **96% (train) but drops to 87% on the test set**.
#   - This **indicates minor overfitting**, as the model generalizes slightly worse than Model 1 and Model 3.
#   - Despite this, **APS (0.99 train, 0.94 test) and ROC AUC (0.99 train, 0.94 test) values remain strong**, showing high predictive confidence.
#   - LGBM is a more powerful classifier but requires careful tuning to prevent overfitting.
#
# ### Summary of Model Choices
# - **Model 1** is a solid, efficient, and well-performing baseline model.
# - **Model 3** introduces spaCy preprocessing, which enhances text representation slightly but does not significantly outperform Model 1.
# - **Model 4** has the highest training accuracy but shows some overfitting. It could be optimized further to maintain generalization.
#
# Considering computational efficiency and performance balance, **Model 1 and Model 3 are the most practical choices** for deployment.

# %% [markdown]
# ## Overall Conclusions
#
# 1. **Baseline Performance (Model 0 - Dummy Classifier)**
#    - Served as a baseline, always predicting the majority class.
#    - Accuracy: **50%**, F1 Score: **0.0** (ineffective for classification).
#
# 2. **TF-IDF + Logistic Regression (Model 1)**
#    - Strong improvement over baseline.
#    - Accuracy: **92% (train), 88% (test)**, F1 Score: **0.92 (train), 0.88 (test)**.
#    - Meets performance thresholds and generalizes well.
#
# 3. **spaCy Preprocessing + TF-IDF + Logistic Regression (Model 3)**
#    - Slightly better than Model 1 with lemmatization and improved feature extraction.
#    - Accuracy: **93% (train), 88% (test)**, F1 Score: **0.93 (train), 0.88 (test)**.
#    - Minimal overfitting, strong generalization.
#
# 4. **spaCy Preprocessing + TF-IDF + LightGBM (Model 4)**
#    - Best performance in training but slight overfitting in testing.
#    - Accuracy: **96% (train), 87% (test)**, F1 Score: **0.96 (train), 0.87 (test)**.
#    - Fast inference speed and strong ranking ability.
#
# ### Final Thoughts
# - **Model 1 and Model 3** balance accuracy and generalization well.
# - **Model 4** shows the highest performance but with slight overfitting.
# - **BERT (Model 9)** was not fully tested due to computational limitations but is expected to improve contextual

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment 4 </h2>
#
# Excellent!
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
# Just don't run BERT. Run everything else, it will take about 20 minutes.
# </div>

# %% [markdown]
# # Checklist

# %% [markdown]
# - [x]  Notebook was opened
# - [ ]  The text data is loaded and pre-processed for vectorization
# - [ ]  The text data is transformed to vectors
# - [ ]  Models are trained and tested
# - [ ]  The metric's threshold is reached
# - [ ]  All the code cells are arranged in the order of their execution
# - [ ]  All the code cells can be executed without errors
# - [ ]  There are conclusions
