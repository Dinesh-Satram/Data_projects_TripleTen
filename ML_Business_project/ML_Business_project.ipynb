# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2 </b>
#
# Thank you very much for the updates! I've left a couple of new comments with digit 2, but there's nothing that needs to be fixed. This is one of the hardest projects, but you did an excellent job! The project is accepted, good luck!
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi Dinesh, I am a reviewer on this project. Congratulations on submitting another machine learning project! 🎉
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content; however, they are convenient, since you can immediately go to them.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> excellent job on this project, thank you so much!
#
#
# - You have successfully prepared the subsets;
#
#
# - Used linear regression to make predictions;
#
#
# - Calculated profit and estimated risk values;
#
#
# - Wrote a great conclusion!
#
#
# However, there are several issues that need your attention. Would you take a look at my comments? It should not take much time. I've also left some recommendations for improving the project.
#
#
# <hr>
#
#
# Here's a nice [article](https://machinelearningmastery.com/a-gentle-introduction-to-the-bootstrap-method/) about the bootstrap method. [This](https://www.youtube.com/watch?v=O_Fj4q8lgmc&list=LL&index=6) is a good video about resampling in bootstrapping.
# </div>

# %% [markdown]
# # **"Optimizing Oil Well Selection: Predictive Modeling, Profit Analysis, and Risk Assessment for OilyGiant Mining Company"**

# %% [markdown]
# ## Introduction

# %% [markdown]
# The **OilyGiant Mining Company** aims to identify the most profitable region for a new oil well. This project uses **machine learning** to predict oil reserves, select the **top 200 most promising wells**, and estimate potential profits. Additionally, **Bootstrapping analysis** is applied to assess financial risks.
#
# By following a structured approach of **data analysis, model training, profit calculation, and risk assessment**, this project provides a data-driven recommendation for oil well development. If no region meets the profitability threshold, the findings will guide future exploration and investment strategies.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# Good introduction!
#
# </div>

# %% [markdown]
# ## Import Required libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randint
from numpy.random import choice

# %% [markdown]
# ## Exploring the Data

# %%
# Load datasets
geo_data_0 = pd.read_csv('/datasets/geo_data_0.csv')
# Display first few rows of each dataset
print("Region 0 Data:")
geo_data_0.head()
# Out:
# Region 0 Data:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
# With dataframes, `display` works better.
#
# </div>

# %%
geo_data_1 = pd.read_csv('/datasets/geo_data_1.csv')
print("\nRegion 1 Data:")
print(geo_data_1.head())
# Out:
# Region 1 Data:
#       id         f0         f1        f2     product
# 0  kBEdx -15.001348  -8.276000 -0.005876    3.179103
# 1  62mP7  14.272088  -3.475083  0.999183   26.953261
# 2  vyE1P   6.263187  -5.948386  5.001160  134.766305
# 3  KcrkZ -13.081196 -11.506057  4.999415  137.945408
# 4  AHL4O  12.702195  -8.147433  5.004363  134.766305

# %%
geo_data_2 = pd.read_csv('/datasets/geo_data_2.csv')
print("\nRegion 2 Data:")
print(geo_data_2.head())
# Out:
# Region 2 Data:
#       id        f0        f1        f2     product
# 0  fwXo0 -1.146987  0.963328 -0.828965   27.758673
# 1  WJtFt  0.262778  0.269839 -2.530187   56.069697
# 2  ovLUW  0.194587  0.289035 -5.586433   62.871910
# 3  q6cA6  2.236060 -0.553760  0.930038  114.572842
# 4  WPMUX -0.515993  1.716266  5.899011  149.600746

# %% [markdown]
# ## Preparing the Data

# %%
# Check for missing values
print("\nMissing values in Region 0:")
print(geo_data_0.isnull().sum())

print("\nMissing values in Region 1:")
print(geo_data_1.isnull().sum())

print("\nMissing values in Region 2:")
print(geo_data_2.isnull().sum())
# Out:
# Missing values in Region 0:
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64
#
# Missing values in Region 1:
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64
#
# Missing values in Region 2:
# id         0
# f0         0
# f1         0
# f2         0
# product    0
# dtype: int64

# %% [markdown]
# There are no missing values, the data is clean and good

# %%
# Check for duplicates
print("\nDuplicate values in datasets:")
print("Region 0:", geo_data_0.duplicated().sum())
print("Region 1:", geo_data_1.duplicated().sum())
print("Region 2:", geo_data_2.duplicated().sum())
# Out:
# Duplicate values in datasets:
# Region 0: 0
# Region 1: 0
# Region 2: 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
# Well done!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
# You can also check for the duplicates in the `id` columns. However, we do not need to delete them if they exist, since these columns will not be considered, and we can interpret these points as different objects.
# </div>

# %% [markdown]
# There are no duplicated values as well

# %%
# Function to plot feature distributions for each region
def plot_feature_distributions(df, region_name):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    features = ['f0', 'f1', 'f2', 'product']
    
    for i, col in enumerate(features):
        sns.histplot(df[col], kde=True, bins=30, color='royalblue', ax=axes[i])
        axes[i].set_title(f"Distribution of {col} - Region {region_name}")
        axes[i].set_xlabel(col)
        axes[i].set_ylabel("Frequency")
    
    plt.suptitle(f"Feature Distributions - Region {region_name}", fontsize=16, fontweight='bold')
    plt.show()

# Generate distribution plots for each region
plot_feature_distributions(geo_data_0, "0")
plot_feature_distributions(geo_data_1, "1")
plot_feature_distributions(geo_data_2, "2")

# %% [markdown]
# ### Conclusions Based on the Distribution Plots
#
# **Region 0:**
# The features f0 and f1 exhibit a multi-modal distribution, indicating that the data is not uniformly distributed and may contain distinct clusters or subgroups.
# The feature f2 has a bell-shaped distribution, suggesting a normal distribution with some variation.
# The target variable product also appears multi-modal, indicating multiple peaks in the reserve quantities, possibly reflecting the presence of different categories or types of wells.
#
# **Region 1:**
# The feature f0 has a bimodal distribution, and f1 has a relatively normal distribution with a slight skew.
# The feature f2 and the target variable product have an unusual pattern with sharp, repeated spikes. This suggests that the data may contain rounded or synthetic values, potentially due to specific sampling or simulation techniques.
# The distribution patterns in Region 1 differ significantly from Regions 0 and 2, which might impact the model’s ability to generalize across regions.
#
# **Region 2:**
# The features f0, f1, and f2 all exhibit bell-shaped, nearly normal distributions, suggesting stable and consistent data patterns in this region.
# The target variable product has a multi-modal distribution, similar to Region 0, indicating variability in oil reserves across wells.
# Compared to Region 1, the distributions in Region 2 appear more natural and consistent.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
#
#
# - Let's add some EDA. Are there any duplicates in the data?
#
#
#
# - Let's analyze the distributions in each dataframe. Would you add charts? Please don't forget to add titles and axes labels.
#
#
# - Don't forget to add a conclusion.
# </div>

# %% [markdown]
# ## Training and Testing the model for each region:

# %%
# Function to train and evaluate the model
def train_and_evaluate(region_data, region_name):
    # Drop 'id' column and split into features and target
    features = region_data.drop(columns=['id', 'product'])
    target = region_data['product']

    # Split data into training (75%) and validation (25%)
    features_train, features_valid, target_train, target_valid = train_test_split(
        features, target, test_size=0.25, random_state=42
    )

    # Train Linear Regression model
    model = LinearRegression()
    model.fit(features_train, target_train)

    # Make predictions
    predictions = model.predict(features_valid)

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(target_valid, predictions))

    # Print results
    print(f"\nRegion {region_name}:")
    print(f"Average predicted reserves: {predictions.mean():.2f} thousand barrels")
    print(f"RMSE: {rmse:.2f} thousand barrels")

    return predictions, target_valid

# Train and evaluate model for each region
predictions_0, target_valid_0 = train_and_evaluate(geo_data_0, "0")
predictions_1, target_valid_1 = train_and_evaluate(geo_data_1, "1")
predictions_2, target_valid_2 = train_and_evaluate(geo_data_2, "2")
# Out:
# Region 0:
# Average predicted reserves: 92.40 thousand barrels
# RMSE: 37.76 thousand barrels
#
# Region 1:
# Average predicted reserves: 68.71 thousand barrels
# RMSE: 0.89 thousand barrels
#
# Region 2:
# Average predicted reserves: 94.77 thousand barrels
# RMSE: 40.15 thousand barrels

# %% [markdown]
# The results from the model evaluation indicate significant differences in prediction accuracy across the three regions. **Region 1** demonstrates the lowest error, with an **RMSE of 0.89 thousand barrels**, suggesting that the model performs exceptionally well in this region and predictions are highly reliable. However, **Region 0 and Region 2** have considerably higher errors, with **RMSE values of 37.76 and 40.15 thousand barrels, respectively**, indicating a greater degree of variability and uncertainty in the predictions. Despite these differences, the average predicted reserves are **92.40 thousand barrels for Region 0, 68.71 thousand barrels for Region 1, and 94.77 thousand barrels for Region 2**. While **Regions 0 and 2** have higher predicted reserves, their high RMSE values introduce greater uncertainty, making their profitability less predictable. **Region 1, although having the lowest predicted reserves, provides the most stable and accurate predictions**, which could be a crucial factor when assessing financial risks and selecting the optimal drilling location.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Great!
#
# </div>

# %% [markdown]
# ## Preparing for profit calculation:

# %% [markdown]
# ### Define Key Business Values

# %%
# Business conditions
BUDGET = 100e6  # 100 million USD
WELLS_SELECTED = 200  # Wells selected for development
BARREL_REVENUE = 4.5e3  # 4.5k USD per thousand barrels

# Calculate the minimum required reserves for profitability
min_reserves_needed = BUDGET / (WELLS_SELECTED * BARREL_REVENUE)

# Print the result
print(f"Minimum reserves required per well to avoid losses: {min_reserves_needed:.2f} thousand barrels")
# Out:
# Minimum reserves required per well to avoid losses: 111.11 thousand barrels

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
#
# Correct!
#
# </div>

# %% [markdown]
# ### Compare with Average Predicted Reserves

# %%
# Calculate actual average reserves for each region
actual_avg_reserves = {
    "Region 0": geo_data_0['product'].mean(),
    "Region 1": geo_data_1['product'].mean(),
    "Region 2": geo_data_2['product'].mean()
}

# Compare actual average reserves with the break-even threshold
print(f"Minimum reserves required per well to avoid losses: {min_reserves_needed:.2f} thousand barrels\n")

for region, avg_reserve in actual_avg_reserves.items():
    print(f"{region}: Actual average reserves = {avg_reserve:.2f} thousand barrels")
    print(f"  - {'Sufficient' if avg_reserve >= min_reserves_needed else 'Insufficient'} reserves for profitability")
# Out:
# Minimum reserves required per well to avoid losses: 111.11 thousand barrels
#
# Region 0: Actual average reserves = 92.50 thousand barrels
#   - Insufficient reserves for profitability
# Region 1: Actual average reserves = 68.83 thousand barrels
#   - Insufficient reserves for profitability
# Region 2: Actual average reserves = 95.00 thousand barrels
#   - Insufficient reserves for profitability

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Let's compare the break-even with the actual average volume in each region because predictions are not necessarily accurate.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# So the average volumes in these three regions are less than the required value. If we are to select the wells randomly, we are probably going to lose money. That's why we need machine learning and bootstrapping to estimate profit distributions.
#
#
# </div>

# %% [markdown]
# ### Findings

# %% [markdown]
# The analysis reveals that the minimum reserves required per well to avoid losses is **111.11 thousand barrels**, but both the **predicted** and **actual average reserves** for all three regions fall below this threshold. The **actual average reserves** are **92.50 thousand barrels for Region 0**, **68.83 thousand barrels for Region 1**, and **95.00 thousand barrels for Region 2**, confirming that none of the regions meet the profitability criteria. This highlights a significant financial risk if wells are selected randomly.
#
# However, profitability may still be achievable by carefully selecting the **top-performing wells** with the highest reserves in each region. To maximize potential returns, the next step is to implement a function to identify the **200 most promising wells** in each region and calculate their expected profit, ensuring that only the most viable extraction sites are considered for development.

# %% [markdown]
# ## Selecting the Best Wells

# %%
def calculate_profit(predictions, target, region_name, verbose=True):
    """
    Function to calculate profit for the top 200 predicted wells.
    """
    # Convert to Pandas Series with unique indices
    predictions = pd.Series(predictions).reset_index(drop=True)
    target = pd.Series(target).reset_index(drop=True)

    # Select top 200 wells based on predicted reserves
    top_wells = predictions.sort_values(ascending=False).head(200)

    # Calculate total actual reserves for selected wells
    total_actual_reserves = target[top_wells.index].sum()

    # Calculate profit
    total_revenue = total_actual_reserves * BARREL_REVENUE  # Total revenue from selected wells
    profit = total_revenue - BUDGET  # Deduct the development budget

    if verbose:  # Print only when verbose=True
        print(f"\nRegion {region_name}:")
        print(f"Total predicted reserves for top 200 wells: {top_wells.sum():.2f} thousand barrels")
        print(f"Total actual reserves from selected wells: {total_actual_reserves:.2f} thousand barrels")
        print(f"Expected profit: ${profit / 1e6:.2f} million")

    return profit
# Calculate profit for each region
profit_0 = calculate_profit(predictions_0, target_valid_0, "0")
profit_1 = calculate_profit(predictions_1, target_valid_1, "1")
profit_2 = calculate_profit(predictions_2, target_valid_2, "2")
# Out:
# Region 0:
# Total predicted reserves for top 200 wells: 30881.46 thousand barrels
# Total actual reserves from selected wells: 29686.98 thousand barrels
# Expected profit: $33.59 million
#
# Region 1:
# Total predicted reserves for top 200 wells: 27748.75 thousand barrels
# Total actual reserves from selected wells: 27589.08 thousand barrels
# Expected profit: $24.15 million
#
# Region 2:
# Total predicted reserves for top 200 wells: 29728.85 thousand barrels
# Total actual reserves from selected wells: 27996.83 thousand barrels
# Expected profit: $25.99 million

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Correct! We select the best 200 wells by predictions, but then we need to use target values to actually calculate profit because predictions may not be accurate.
#
# </div>

# %% [markdown]
# ### Findings and Suggested Region for Development

# %% [markdown]
# Based on the profit calculation, Region 0 emerges as the most viable location for oil well development. The top 200 wells in this region have an expected profit of $33.59 million, which is higher than both Region 1 ($24.15M) and Region 2 ($25.99M). While Region 1 has the most stable model predictions (lowest RMSE), its lower predicted reserves lead to lower total profits. Region 2 has slightly higher total reserves than Region 1, but still falls short of Region 0’s profitability.
#
# Given the business objective of maximizing profit while mitigating risks, Region 0 is the best candidate for oil well development. However, before making a final decision, we need to assess the risks and uncertainties associated with each region’s expected profit.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# Use `\` or `\\` before the `$` character. Then `\$27,103,499.64` will be displayed correctly: \$27,103,499.64.
#
#
# </div>

# %% [markdown]
# ## Implementing Bootstrapping

# %%
# Bootstrapping function using `calculate_profit`
def bootstrap_profit_analysis(predictions, target, region_name, n_samples=1000):
    """
    Perform bootstrapping to analyze profit distribution using the calculate_profit function.
    """
    # Ensure predictions and target are Pandas Series with unique indices
    predictions = pd.Series(predictions).reset_index(drop=True)
    target = pd.Series(target).reset_index(drop=True)

    profits = []

    for _ in range(n_samples):
        # Sample 500 wells by position with replacement
        sampled_indices = randint(0, len(target), size=500)

        # Use `calculate_profit` with `verbose=False` to avoid excessive printing
        profit = calculate_profit(predictions.iloc[sampled_indices], target.iloc[sampled_indices], region_name=None, verbose=False)
        profits.append(profit)

    # Convert profits to NumPy array
    profits = np.array(profits)

    # Calculate statistics
    mean_profit = profits.mean()
    lower_bound = np.percentile(profits, 2.5)  # 2.5% percentile
    upper_bound = np.percentile(profits, 97.5)  # 97.5% percentile
    risk_of_loss = (profits < 0).mean() * 100  # Percentage of negative profit

    # Print final bootstrapping results
    print(f"\nRegion {region_name} - Bootstrapping Analysis:")
    print(f"Average Expected Profit: ${mean_profit / 1e6:.2f} million")
    print(f"95% Confidence Interval: (${lower_bound / 1e6:.2f}M, ${upper_bound / 1e6:.2f}M)")
    print(f"Risk of Loss: {risk_of_loss:.2f}%")

    return mean_profit, lower_bound, upper_bound, risk_of_loss

# Run bootstrapping for each region
mean_profit_0, lower_0, upper_0, risk_0 = bootstrap_profit_analysis(predictions_0, target_valid_0, "0")
mean_profit_1, lower_1, upper_1, risk_1 = bootstrap_profit_analysis(predictions_1, target_valid_1, "1")
mean_profit_2, lower_2, upper_2, risk_2 = bootstrap_profit_analysis(predictions_2, target_valid_2, "2")
# Out:
# Region 0 - Bootstrapping Analysis:
# Average Expected Profit: $4.11 million
# 95% Confidence Interval: ($-0.80M, $9.23M)
# Risk of Loss: 5.40%
#
# Region 1 - Bootstrapping Analysis:
# Average Expected Profit: $4.51 million
# 95% Confidence Interval: ($0.55M, $8.40M)
# Risk of Loss: 1.20%
#
# Region 2 - Bootstrapping Analysis:
# Average Expected Profit: $3.80 million
# 95% Confidence Interval: ($-1.32M, $8.74M)
# Risk of Loss: 8.80%

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# There's a replacement, well done!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# - We need to sample 500 rows.
#
#
#
# - We defined the profit function above in order to avoid repetitions. Please try to use this function in the bootstrapping loop.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Correct!
#
# </div>

# %% [markdown]
# ### Findings on Region Selection

# %% [markdown]
# The Bootstrapping analysis reveals that the risk of loss varies across regions, with Region 1 having the lowest risk at 1.20%, while Region 2 has the highest risk at 8.80%. This suggests that Region 1 is the most stable and least risky option for investment.
#
# Region 1 has the highest average expected profit of \\$4.51M, with a 95% confidence interval of (\\$0.55M to \\$8.40M) and a low risk of loss (1.20%). This indicates that investing in Region 1 is the safest option, as losses are minimal in most simulations.
# Region 0 shows an average expected profit of $4.11M, with a 95% confidence interval of (\\$-0.80M to \$9.23M) and a moderate risk of loss (5.40%). While this region has a positive expected profit, its risk level is higher than Region 1, making it a less favorable option.
# Region 2 has the lowest expected profit of \\$3.80M and the highest risk of loss (8.80%), with a 95% confidence interval of ($-1.32M to \\$8.74M). The high variability and negative lower bound indicate that this region carries the highest financial risk.

# %% [markdown]
# ## Overall Conclusion

# %% [markdown]
# This project aimed to **identify the most profitable region** for oil well development using **machine learning and statistical analysis**. We analyzed data from **three regions**, trained **Linear Regression models** to predict oil reserves, and used **Bootstrapping** to assess financial risks.
#
# ### **Key Findings:**
#
# 1. **Model Performance:**
#    - **Region 1 had the most accurate predictions** (RMSE: **0.89k barrels**), while **Regions 0 and 2 had higher RMSE values** (**37.76k and 40.15k barrels**).
#    - Despite its accuracy, **Region 1 had the lowest average predicted reserves (68.71k barrels)**.
#
# 2. **Profitability & Risk Assessment:**
#    - The **minimum reserves required per well** was **111.11k barrels**, but all regions had lower averages, posing financial risks.
#    - **Region 1 had the highest financial stability** with an **expected profit of $4.51M** and the **lowest risk of loss (1.20%)**.
#    - **Region 0 had a moderate risk (5.40%)** with an **expected profit of $4.11M**, while **Region 2 had the highest risk (8.80%)**, making it the least favorable.
#
# ### **Final Decision:**
# **Region 1 is the best choice** for oil well development due to its **highest financial stability and lowest risk**. **Investments should be prioritized in Region 1** to maximize returns while minimizing losses.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Good conclusion!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Please don't forget to update it :)
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Excellent!
#
# </div>
